# %% [markdown]
# # Lecture 6 : Dataframe

# %% [markdown]
# * Pandas is an open source Python library for data analysis. It is very powerful toolkit for reading, filtering, manipulating and exporting data.
# * Since Pandas is not part of the Python standard library, you have to first tell Python to load the library.
# * When working with Pandas functions, it is common practice to give pandas the alias pd.

# %%
import pandas as pd

# %% [markdown]
# ## 1. Series

# %% [markdown]
# * The Series is a one-dimensional container, similar to the built-in Python list. It is the data type that represents each column of the DataFrame.
# * The easiest way to create a Series is to pass in a Python list. If we pass in a list of mixed types, the most common representation of both will be used. Typically the dtype will be object.

# %%
s = pd.Series(['apple', 10])

print(s)
# Out:
# 0    apple
# 1       10
# dtype: object

# %% [markdown]
# * Notice on the left that the "row number" is shown. This is actually the **index** for the series. It is similar to the row name and row index for dataframes. It implies that we can actually assign a "name" to values in our series.

# %%
covid = pd.Series([79293924, 42631421, 27425743, 21622265, 18266015], index=['USA', 'India', 'Brazil', 'France', 'UK'])

print(covid)
# Out:
# USA       79293924
# India     42631421
# Brazil    27425743
# France    21622265
# UK        18266015
# dtype: int64

# %% [markdown]
# * There are many attributes and methods associated with a **Series** object. Two examples of attributes are **index** and **values**.

# %%
covid.index
# Out:
# Index(['USA', 'India', 'Brazil', 'France', 'UK'], dtype='object')

# %%
covid.values
# Out:
# array([79293924, 42631421, 27425743, 21622265, 18266015])

# %%
covid['USA']
# Out:
# 79293924

# %% [markdown]
# * You can get a summarize of statistics of the series by .describe().

# %%
covid.describe()
# Out:
# count    5.000000e+00
# mean     3.784787e+07
# std      2.497998e+07
# min      1.826602e+07
# 25%      2.162226e+07
# 50%      2.742574e+07
# 75%      4.263142e+07
# max      7.929392e+07
# dtype: float64

# %%
covid.mean()
# Out:
# 37847873.6

# %%
covid.median()
# Out:
# 27425743.0

# %% [markdown]
# * What if we wanted to subset the series by identifying those of the mean?

# %%
covid
# Out:
# USA       79293924
# India     42631421
# Brazil    27425743
# France    21622265
# UK        18266015
# dtype: int64

# %%
covid[covid>covid.mean()]
# Out:
# USA      79293924
# India    42631421
# dtype: int64

# %%
covid[covid>covid.mean()]
# Out:
# USA      79293924
# India    42631421
# dtype: int64

# %% [markdown]
# ## 2. DataFrame

# %% [markdown]
# * Dataframe can be created through the combination of **key** - **values**.
# * The **key** represents the column namem and the **values** are the contents of the column.

# %%
df = pd.DataFrame({'country': ['USA', 'India', 'Brazil', 'France', 'UK'], 'confirmed': [79293924, 42631421, 27425743, 21622265, 18266015],
                          'population': [333214298, 1387953387, 214341966, 67813000, 67081234]})

# %%
df
# Out:
#   country  confirmed  population
# 0     USA   79293924   333214298
# 1   India   42631421  1387953387
# 2  Brazil   27425743   214341966
# 3  France   21622265    67813000
# 4      UK   18266015    67081234

# %%
df['country']
# Out:
# 0       USA
# 1     India
# 2    Brazil
# 3    France
# 4        UK
# Name: country, dtype: object

# %% [markdown]
# * Every DataFrame object has a shape attribute that will give us the number of rows and columns of the DataFrame.

# %%
df.shape
# Out:
# (5, 3)

# %% [markdown]
# * To get the list of which information it contains, we look at the columns.

# %%
df.columns
# Out:
# Index(['country', 'confirmed', 'population'], dtype='object')

# %% [markdown]
# * You can check the data types of each column by using the dtypes attribute.

# %%
df.dtypes
# Out:
# country       object
# confirmed      int64
# population     int64
# dtype: object

# %% [markdown]
# ### Loading dataset

# %% [markdown]
# * With the pandas library loaded, we can use the read_csv function to load a CSV data file.
# * You can also load different types of data like JSON, HTML, EXCEL, SAS, etc.
# https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html

# %%
mlb_winloss = pd.read_csv('./mlb_winloss.csv')

######## For Colab users ########
#import io
#from google.colab import files
#uploaded = files.upload()
#mlb_winloss = pd.read_csv(io.StringIO(uploaded['mlb_winloss.csv'].decode('utf-8')))

# %%
mlb_winloss
# Out:
#     Rank                   Team     Won    Lost  Tied  First MLB Season  \
# 0      1       New York Yankees  10,621   8,090    93              1901
# 1      2   San Francisco Giants  11,301   9,773   163              1883
# 2      3    Los Angeles Dodgers  11,123   9,891   139              1884
# 3      4    St. Louis Cardinals  11,038  10,163   152              1882
# 4      5         Boston Red Sox   9,718   9,014    83              1901
# 5      6           Chicago Cubs  11,087  10,521   161              1876
# 6      7    Cleveland Guardians   9,592   9,144    91              1901
# 7      8        Cincinnati Reds  10,713  10,501   139              1882
# 8      9         Detroit Tigers   9,446   9,311    93              1901
# 9     10      Chicago White Sox   9,411   9,309   103              1901
# 10    11     Pittsburgh Pirates  10,625  10,547   140              1882
# 11    12         Atlanta Braves  10,820  10,757   154              1876
# 12    13     Los Angeles Angels   4,812   4,838     3              1961
# 13    14         Houston Astros   4,725   4,764     5              1962
# 14    15      Toronto Blue Jays   3,506   3,557     3              1977
# 15    16      Oakland Athletics   9,150   9,552    87              1901
# 16    17   Washington Nationals   4,068   4,280     4              1969
# 17    18   Arizona Diamondbacks   1,840   1,946     0              1998
# 18    19      Milwaukee Brewers   4,037   4,315     4              1969
# 19    20         Tampa Bay Rays   1,826   1,958     0              1998
# 20    21        Minnesota Twins   9,012   9,716   109              1901
# 21    22          New York Mets   4,551   4,927     8              1962
# 22    23     Kansas City Royals   4,001   4,344     2              1969
# 23    24          Texas Rangers   4,582   5,052     6              1961
# 24    25      Baltimore Orioles   8,845   9,873   110              1901
# 25    26       Seattle Mariners   3,336   3,727     2              1977
# 26    27  Philadelphia Phillies   9,935  11,112   115              1883
# 27    28       Colorado Rockies   2,133   2,401     0              1993
# 28    29       San Diego Padres   3,863   4,495     2              1969
# 29    30          Miami Marlins   2,088   2,438     0              1993
#
#       Division
# 0      AL East
# 1      NL West
# 2      NL West
# 3   NL Central
# 4      AL East
# 5   NL Central
# 6   AL Central
# 7   NL Central
# 8   AL Central
# 9   AL Central
# 10  NL Central
# 11     NL East
# 12     AL West
# 13     AL West
# 14     AL East
# 15     AL West
# 16     NL East
# 17     NL West
# 18  NL Central
# 19     AL East
# 20  AL Central
# 21     NL East
# 22  AL Central
# 23     AL West
# 24     AL East
# 25     AL West
# 26     NL East
# 27     NL West
# 28     NL West
# 29     NL East

# %% [markdown]
# * A DataFrame is similar to Excel workbook tabular datasheet.

# %%
mlb_winloss.head()
# Out:
#    Rank                  Team     Won    Lost  Tied  First MLB Season  \
# 0     1      New York Yankees  10,621   8,090    93              1901
# 1     2  San Francisco Giants  11,301   9,773   163              1883
# 2     3   Los Angeles Dodgers  11,123   9,891   139              1884
# 3     4   St. Louis Cardinals  11,038  10,163   152              1882
# 4     5        Boston Red Sox   9,718   9,014    83              1901
#
#      Division
# 0     AL East
# 1     NL West
# 2     NL West
# 3  NL Central
# 4     AL East

# %%
mlb_winloss.head(10)
# Out:
#    Rank                  Team     Won    Lost  Tied  First MLB Season  \
# 0     1      New York Yankees  10,621   8,090    93              1901
# 1     2  San Francisco Giants  11,301   9,773   163              1883
# 2     3   Los Angeles Dodgers  11,123   9,891   139              1884
# 3     4   St. Louis Cardinals  11,038  10,163   152              1882
# 4     5        Boston Red Sox   9,718   9,014    83              1901
# 5     6          Chicago Cubs  11,087  10,521   161              1876
# 6     7   Cleveland Guardians   9,592   9,144    91              1901
# 7     8       Cincinnati Reds  10,713  10,501   139              1882
# 8     9        Detroit Tigers   9,446   9,311    93              1901
# 9    10     Chicago White Sox   9,411   9,309   103              1901
#
#      Division
# 0     AL East
# 1     NL West
# 2     NL West
# 3  NL Central
# 4     AL East
# 5  NL Central
# 6  AL Central
# 7  NL Central
# 8  AL Central
# 9  AL Central

# %%
mlb_winloss.tail(10)
# Out:
#     Rank                   Team    Won    Lost  Tied  First MLB Season  \
# 20    21        Minnesota Twins  9,012   9,716   109              1901
# 21    22          New York Mets  4,551   4,927     8              1962
# 22    23     Kansas City Royals  4,001   4,344     2              1969
# 23    24          Texas Rangers  4,582   5,052     6              1961
# 24    25      Baltimore Orioles  8,845   9,873   110              1901
# 25    26       Seattle Mariners  3,336   3,727     2              1977
# 26    27  Philadelphia Phillies  9,935  11,112   115              1883
# 27    28       Colorado Rockies  2,133   2,401     0              1993
# 28    29       San Diego Padres  3,863   4,495     2              1969
# 29    30          Miami Marlins  2,088   2,438     0              1993
#
#       Division
# 20  AL Central
# 21     NL East
# 22  AL Central
# 23     AL West
# 24     AL East
# 25     AL West
# 26     NL East
# 27     NL West
# 28     NL West
# 29     NL East

# %%
len(mlb_winloss)
# Out:
# 30

# %%
mlb_winloss.shape
# Out:
# (30, 7)

# %% [markdown]
# ### Subsetting columns and rows
#
# * Today's data often has too many cells to make sense of all the printed information. Instead, the best way to look at our data is to inspect it in parts by looking at various subsets of the data.
# * We already saw that we can use the **head** method of a dataframe to look at the first five rows of our data. This is useful to see if our data loaded properly and to get a sense of each of the columns, its name, and its contents.
# * Sometimes, however, we may want to see only particular rows, columns, or values from our data.

# %% [markdown]
# * If we want only a specific column from our data, we can access the data using square brackets.

# %%
mlb_winloss['Team']
# Out:
# 0          New York Yankees
# 1      San Francisco Giants
# 2       Los Angeles Dodgers
# 3       St. Louis Cardinals
# 4            Boston Red Sox
# 5              Chicago Cubs
# 6       Cleveland Guardians
# 7           Cincinnati Reds
# 8            Detroit Tigers
# 9         Chicago White Sox
# 10       Pittsburgh Pirates
# 11           Atlanta Braves
# 12       Los Angeles Angels
# 13           Houston Astros
# 14        Toronto Blue Jays
# 15        Oakland Athletics
# 16     Washington Nationals
# 17     Arizona Diamondbacks
# 18        Milwaukee Brewers
# 19           Tampa Bay Rays
# 20          Minnesota Twins
# 21            New York Mets
# 22       Kansas City Royals
# 23            Texas Rangers
# 24        Baltimore Orioles
# 25         Seattle Mariners
# 26    Philadelphia Phillies
# 27         Colorado Rockies
# 28         San Diego Padres
# 29            Miami Marlins
# Name: Team, dtype: object

# %%
mlb_winloss.head()
# Out:
#    Rank                  Team     Won    Lost  Tied  First MLB Season  \
# 0     1      New York Yankees  10,621   8,090    93              1901
# 1     2  San Francisco Giants  11,301   9,773   163              1883
# 2     3   Los Angeles Dodgers  11,123   9,891   139              1884
# 3     4   St. Louis Cardinals  11,038  10,163   152              1882
# 4     5        Boston Red Sox   9,718   9,014    83              1901
#
#      Division
# 0     AL East
# 1     NL West
# 2     NL West
# 3  NL Central
# 4     AL East

# %% [markdown]
# * To specify multiple columns by the column name, we need to pass in a list between the square brackets

# %%
mlb_winloss[['Rank', 'Team']]
# Out:
#     Rank                   Team
# 0      1       New York Yankees
# 1      2   San Francisco Giants
# 2      3    Los Angeles Dodgers
# 3      4    St. Louis Cardinals
# 4      5         Boston Red Sox
# 5      6           Chicago Cubs
# 6      7    Cleveland Guardians
# 7      8        Cincinnati Reds
# 8      9         Detroit Tigers
# 9     10      Chicago White Sox
# 10    11     Pittsburgh Pirates
# 11    12         Atlanta Braves
# 12    13     Los Angeles Angels
# 13    14         Houston Astros
# 14    15      Toronto Blue Jays
# 15    16      Oakland Athletics
# 16    17   Washington Nationals
# 17    18   Arizona Diamondbacks
# 18    19      Milwaukee Brewers
# 19    20         Tampa Bay Rays
# 20    21        Minnesota Twins
# 21    22          New York Mets
# 22    23     Kansas City Royals
# 23    24          Texas Rangers
# 24    25      Baltimore Orioles
# 25    26       Seattle Mariners
# 26    27  Philadelphia Phillies
# 27    28       Colorado Rockies
# 28    29       San Diego Padres
# 29    30          Miami Marlins

# %% [markdown]
# * We can use the loc attribute on the dataframe to subset rows based on the index label.

# %%
mlb_winloss.head()
# Out:
#    Rank                  Team     Won    Lost  Tied  First MLB Season  \
# 0     1      New York Yankees  10,621   8,090    93              1901
# 1     2  San Francisco Giants  11,301   9,773   163              1883
# 2     3   Los Angeles Dodgers  11,123   9,891   139              1884
# 3     4   St. Louis Cardinals  11,038  10,163   152              1882
# 4     5        Boston Red Sox   9,718   9,014    83              1901
#
#      Division
# 0     AL East
# 1     NL West
# 2     NL West
# 3  NL Central
# 4     AL East

# %%
mlb_winloss.loc[0]
# Out:
# Rank                               1
# Team                New York Yankees
# Won                           10,621
# Lost                           8,090
# Tied                              93
# First MLB Season                1901
# Division                     AL East
# Name: 0, dtype: object

# %%
mlb_winloss.loc[[0, 2, 4]]
# Out:
#    Rank                 Team     Won   Lost  Tied  First MLB Season Division
# 0     1     New York Yankees  10,621  8,090    93              1901  AL East
# 2     3  Los Angeles Dodgers  11,123  9,891   139              1884  NL West
# 4     5       Boston Red Sox   9,718  9,014    83              1901  AL East

# %%
mlb_winloss.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-2e8185bf7d1c> in <module>
# ----> 1 mlb_winloss.loc[-1]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: -1

# %% [markdown]
# * iloc is used to subset by the row index number.

# %%
mlb_winloss.iloc[0]
# Out:
# Rank                               1
# Team                New York Yankees
# Won                           10,621
# Lost                           8,090
# Tied                              93
# First MLB Season                1901
# Division                     AL East
# Name: 0, dtype: object

# %%
mlb_winloss.iloc[-1]
# Out:
# Rank                           30
# Team                Miami Marlins
# Won                         2,088
# Lost                        2,438
# Tied                            0
# First MLB Season             1993
# Division                  NL East
# Name: 29, dtype: object

# %%
mlb_winloss2 = mlb_winloss.tail()

# %%
mlb_winloss2
# Out:
#     Rank                   Team    Won    Lost  Tied  First MLB Season  \
# 25    26       Seattle Mariners  3,336   3,727     2              1977
# 26    27  Philadelphia Phillies  9,935  11,112   115              1883
# 27    28       Colorado Rockies  2,133   2,401     0              1993
# 28    29       San Diego Padres  3,863   4,495     2              1969
# 29    30          Miami Marlins  2,088   2,438     0              1993
#
#    Division
# 25  AL West
# 26  NL East
# 27  NL West
# 28  NL West
# 29  NL East

# %%
mlb_winloss2.iloc[0]
# Out:
# Rank                              26
# Team                Seattle Mariners
# Won                            3,336
# Lost                           3,727
# Tied                               2
# First MLB Season                1977
# Division                     AL West
# Name: 25, dtype: object

# %% [markdown]
# * If we just want to get the second and third column using the loc or iloc syntax, we can write

# %%
mlb_winloss.loc[0]
# Out:
# Rank                               1
# Team                New York Yankees
# Won                           10,621
# Lost                           8,090
# Tied                              93
# First MLB Season                1901
# Division                     AL East
# Name: 0, dtype: object

# %%
mlb_winloss.loc[0,['Rank', 'Team']]
# Out:
# Rank                   1
# Team    New York Yankees
# Name: 0, dtype: object

# %%
mlb_winloss[['Rank', 'Team']]
# Out:
#     Rank                   Team
# 0      1       New York Yankees
# 1      2   San Francisco Giants
# 2      3    Los Angeles Dodgers
# 3      4    St. Louis Cardinals
# 4      5         Boston Red Sox
# 5      6           Chicago Cubs
# 6      7    Cleveland Guardians
# 7      8        Cincinnati Reds
# 8      9         Detroit Tigers
# 9     10      Chicago White Sox
# 10    11     Pittsburgh Pirates
# 11    12         Atlanta Braves
# 12    13     Los Angeles Angels
# 13    14         Houston Astros
# 14    15      Toronto Blue Jays
# 15    16      Oakland Athletics
# 16    17   Washington Nationals
# 17    18   Arizona Diamondbacks
# 18    19      Milwaukee Brewers
# 19    20         Tampa Bay Rays
# 20    21        Minnesota Twins
# 21    22          New York Mets
# 22    23     Kansas City Royals
# 23    24          Texas Rangers
# 24    25      Baltimore Orioles
# 25    26       Seattle Mariners
# 26    27  Philadelphia Phillies
# 27    28       Colorado Rockies
# 28    29       San Diego Padres
# 29    30          Miami Marlins

# %%
mlb_winloss.loc[:,['Rank', 'Team']]
# Out:
#     Rank                   Team
# 0      1       New York Yankees
# 1      2   San Francisco Giants
# 2      3    Los Angeles Dodgers
# 3      4    St. Louis Cardinals
# 4      5         Boston Red Sox
# 5      6           Chicago Cubs
# 6      7    Cleveland Guardians
# 7      8        Cincinnati Reds
# 8      9         Detroit Tigers
# 9     10      Chicago White Sox
# 10    11     Pittsburgh Pirates
# 11    12         Atlanta Braves
# 12    13     Los Angeles Angels
# 13    14         Houston Astros
# 14    15      Toronto Blue Jays
# 15    16      Oakland Athletics
# 16    17   Washington Nationals
# 17    18   Arizona Diamondbacks
# 18    19      Milwaukee Brewers
# 19    20         Tampa Bay Rays
# 20    21        Minnesota Twins
# 21    22          New York Mets
# 22    23     Kansas City Royals
# 23    24          Texas Rangers
# 24    25      Baltimore Orioles
# 25    26       Seattle Mariners
# 26    27  Philadelphia Phillies
# 27    28       Colorado Rockies
# 28    29       San Diego Padres
# 29    30          Miami Marlins

# %%
mlb_winloss.iloc[:,5]
# Out:
# 0     1901
# 1     1883
# 2     1884
# 3     1882
# 4     1901
# 5     1876
# 6     1901
# 7     1882
# 8     1901
# 9     1901
# 10    1882
# 11    1876
# 12    1961
# 13    1962
# 14    1977
# 15    1901
# 16    1969
# 17    1998
# 18    1969
# 19    1998
# 20    1901
# 21    1962
# 22    1969
# 23    1961
# 24    1901
# 25    1977
# 26    1883
# 27    1993
# 28    1969
# 29    1993
# Name: First MLB Season, dtype: int64

# %% [markdown]
# * You can subset columns through generating range list.

# %%
mlb_winloss.iloc[:,range(1,4)]
# Out:
#                      Team     Won    Lost
# 0        New York Yankees  10,621   8,090
# 1    San Francisco Giants  11,301   9,773
# 2     Los Angeles Dodgers  11,123   9,891
# 3     St. Louis Cardinals  11,038  10,163
# 4          Boston Red Sox   9,718   9,014
# 5            Chicago Cubs  11,087  10,521
# 6     Cleveland Guardians   9,592   9,144
# 7         Cincinnati Reds  10,713  10,501
# 8          Detroit Tigers   9,446   9,311
# 9       Chicago White Sox   9,411   9,309
# 10     Pittsburgh Pirates  10,625  10,547
# 11         Atlanta Braves  10,820  10,757
# 12     Los Angeles Angels   4,812   4,838
# 13         Houston Astros   4,725   4,764
# 14      Toronto Blue Jays   3,506   3,557
# 15      Oakland Athletics   9,150   9,552
# 16   Washington Nationals   4,068   4,280
# 17   Arizona Diamondbacks   1,840   1,946
# 18      Milwaukee Brewers   4,037   4,315
# 19         Tampa Bay Rays   1,826   1,958
# 20        Minnesota Twins   9,012   9,716
# 21          New York Mets   4,551   4,927
# 22     Kansas City Royals   4,001   4,344
# 23          Texas Rangers   4,582   5,052
# 24      Baltimore Orioles   8,845   9,873
# 25       Seattle Mariners   3,336   3,727
# 26  Philadelphia Phillies   9,935  11,112
# 27       Colorado Rockies   2,133   2,401
# 28       San Diego Padres   3,863   4,495
# 29          Miami Marlins   2,088   2,438

# %% [markdown]
# * Same as the **Series**, we can subset a dataframe with a boolean subsetting.

# %%
mlb_winloss.head()
# Out:
#    Rank                  Team     Won    Lost  Tied  First MLB Season  \
# 0     1      New York Yankees  10,621   8,090    93              1901
# 1     2  San Francisco Giants  11,301   9,773   163              1883
# 2     3   Los Angeles Dodgers  11,123   9,891   139              1884
# 3     4   St. Louis Cardinals  11,038  10,163   152              1882
# 4     5        Boston Red Sox   9,718   9,014    83              1901
#
#      Division
# 0     AL East
# 1     NL West
# 2     NL West
# 3  NL Central
# 4     AL East

# %%
mlb_winloss[mlb_winloss['First MLB Season']>1990]
# Out:
#     Rank                  Team    Won   Lost  Tied  First MLB Season Division
# 17    18  Arizona Diamondbacks  1,840  1,946     0              1998  NL West
# 19    20        Tampa Bay Rays  1,826  1,958     0              1998  AL East
# 27    28      Colorado Rockies  2,133  2,401     0              1993  NL West
# 29    30         Miami Marlins  2,088  2,438     0              1993  NL East

# %%
mlb_winloss[mlb_winloss['Division']=='NL West']
# Out:
#     Rank                  Team     Won   Lost  Tied  First MLB Season Division
# 1      2  San Francisco Giants  11,301  9,773   163              1883  NL West
# 2      3   Los Angeles Dodgers  11,123  9,891   139              1884  NL West
# 17    18  Arizona Diamondbacks   1,840  1,946     0              1998  NL West
# 27    28      Colorado Rockies   2,133  2,401     0              1993  NL West
# 28    29      San Diego Padres   3,863  4,495     2              1969  NL West

# %%
mlb_winloss.head()
# Out:
#    Rank                  Team     Won    Lost  Tied  First MLB Season  \
# 0     1      New York Yankees  10,621   8,090    93              1901
# 1     2  San Francisco Giants  11,301   9,773   163              1883
# 2     3   Los Angeles Dodgers  11,123   9,891   139              1884
# 3     4   St. Louis Cardinals  11,038  10,163   152              1882
# 4     5        Boston Red Sox   9,718   9,014    83              1901
#
#      Division
# 0     AL East
# 1     NL West
# 2     NL West
# 3  NL Central
# 4     AL East

# %% [markdown]
# * You can insert a new column in the dataframe.

# %%
mlb_winloss['age'] = 2022 - mlb_winloss['First MLB Season']

# %%
mlb_winloss.head()
# Out:
#    Rank                  Team     Won    Lost  Tied  First MLB Season  \
# 0     1      New York Yankees  10,621   8,090    93              1901
# 1     2  San Francisco Giants  11,301   9,773   163              1883
# 2     3   Los Angeles Dodgers  11,123   9,891   139              1884
# 3     4   St. Louis Cardinals  11,038  10,163   152              1882
# 4     5        Boston Red Sox   9,718   9,014    83              1901
#
#      Division  age
# 0     AL East  121
# 1     NL West  139
# 2     NL West  138
# 3  NL Central  140
# 4     AL East  121

# %%
mlb_winloss['city'] = 'None'
mlb_winloss.head()
# Out:
#    Rank                  Team     Won    Lost  Tied  First MLB Season  \
# 0     1      New York Yankees  10,621   8,090    93              1901
# 1     2  San Francisco Giants  11,301   9,773   163              1883
# 2     3   Los Angeles Dodgers  11,123   9,891   139              1884
# 3     4   St. Louis Cardinals  11,038  10,163   152              1882
# 4     5        Boston Red Sox   9,718   9,014    83              1901
#
#      Division  age  city
# 0     AL East  121  None
# 1     NL West  139  None
# 2     NL West  138  None
# 3  NL Central  140  None
# 4     AL East  121  None

# %%
del mlb_winloss['city']

# %%
mlb_winloss.head()
# Out:
#    Rank                  Team     Won    Lost  Tied  First MLB Season  \
# 0     1      New York Yankees  10,621   8,090    93              1901
# 1     2  San Francisco Giants  11,301   9,773   163              1883
# 2     3   Los Angeles Dodgers  11,123   9,891   139              1884
# 3     4   St. Louis Cardinals  11,038  10,163   152              1882
# 4     5        Boston Red Sox   9,718   9,014    83              1901
#
#      Division  age
# 0     AL East  121
# 1     NL West  139
# 2     NL West  138
# 3  NL Central  140
# 4     AL East  121

# %% [markdown]
# ### Describe your data

# %% [markdown]
# * describe() is used to view some basic statistical details like percentile, mean, std etc. of a dataframe.

# %%
mlb_winloss.describe()
# Out:
#             Rank      Tied  First MLB Season         age
# count  30.000000   30.0000         30.000000   30.000000
# mean   15.500000   65.7000       1930.466667   91.533333
# std     8.803408   63.2718         44.589107   44.589107
# min     1.000000    0.0000       1876.000000   24.000000
# 25%     8.250000    3.0000       1888.250000   53.000000
# 50%    15.500000   85.0000       1901.000000  121.000000
# 75%    22.750000  113.7500       1969.000000  133.750000
# max    30.000000  163.0000       1998.000000  146.000000

# %% [markdown]
# * Where are Won, Lost, Total Games?

# %%
mlb_winloss.dtypes
# Out:
# Rank                 int64
# Team                object
# Won                 object
# Lost                object
# Tied                 int64
# First MLB Season     int64
# Division            object
# age                  int64
# dtype: object

# %% [markdown]
# ## Exercise

# %% [markdown]
# 1. Load(read) the automobile data (automobile_data.csv)

# %%
# your code here

# %% [markdown]
# 2. Print the first five rows.

# %%
# your code here

# %% [markdown]
# 3. Print the last ten rows.

# %%
# your code here

# %% [markdown]
# 4. How many rows and columns of the DataFrame?

# %%
# your code here

# %% [markdown]
# 5. Print the 10th and 20th rows of the DataFrame.

# %%
# your code here

# %% [markdown]
# 6. Print the columes (from 5th to 7th one).

# %%
# your code here

# %% [markdown]
# 7. How many automobiles does have horsepower with greater than 100?

# %%
# your code here

# %% [markdown]
# 8. How many automobiles are cheaper than 6000?

# %%
# your code here

# %% [markdown]
# ## References
# * Chen, D. Y. (2017). Pandas for everyone: Python data analysis. Addison-Wesley Professional.
# * Data Analysis with Python: https://www.coursera.org/learn/data-analysis-with-python
# * https://pandas.pydata.org/
